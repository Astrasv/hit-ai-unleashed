# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Initializing model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
)

response = model.invoke("What's the capital India?")
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# # Creating a plain agent

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model
)
# Out:
# d:\A_Projects\A_ Git hosted\ai_unleashed_hit\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {
        "messages": [
            HumanMessage(content="What's the capital of the India?")
        ]
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='082f237e-9232-47e8-ad56-573cae06e886'),
#               AIMessage(content="That's a fun question that plays on our understanding of what a capital city is!\n\nThe Moon doesn't have a capital city because it's not a country or a territory with human settlements, governments, or organized populations like we have on Earth.\n\nSo, the answer is: **The Moon does not have a capital.**", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ddd13-dd86-7db1-98b0-8fba78e11f1e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 69, 'total_tokens': 79, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response["messages"][-1].content)
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {
        "messages": [
            HumanMessage(content="What's the capital of India?"),
            AIMessage(content="The capital of India is New Delhi."),
            HumanMessage(content="Interesting, tell me more about New Delhi"),
        ]
    }
)

print(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='138a135a-0525-4c53-922e-1c984396e0ab'), AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='39930199-f94b-475a-9d5f-9bdf8ea232ac', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='1e3343d7-6354-4612-9852-9b62c1bdb8da'), AIMessage(content='Luna City is a fictional city on the Moon, serving as the capital in a number of science fiction stories and concepts. It\'s often depicted as a bustling metropolis, a hub of lunar life, and a center of government and commerce.\n\nHere are some common themes and characteristics associated with Luna City:\n\n*   **Location:** It\'s usually envisioned as being built within a large crater, a lava tube, or a specially constructed dome to protect its inhabitants from the harsh lunar
# ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {
        "messages": [
            HumanMessage(content="Tell me all about New Delhi, the capital of India")
        ]
    },
    stream_mode="messages",
):


    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# New Delhi is a fascinating and multifaceted city, serving as the capital of India and a vibrant hub of history, culture, politics, and modern life. Here's a comprehensive overview:
#
# **A City of Contrasts and Layers:**
#
# New Delhi is not a single, monolithic entity. It's best understood as a blend of:
#
# * **Old Delhi:** The historic heart of the city, established by Mughal Emperor Shah Jahan in the 17th century. It's a labyrinth of narrow lanes, bustling bazaars, and magnificent Mughal architecture.
# * **New Delhi:** The planned capital city, designed by British architects Edwin Lutyens and Herbert Baker in the early 20th century. It's characterized by grand boulevards, wide avenues, imposing government buildings, and lush green spaces.
#
# **Key Aspects of New Delhi:**
#
# **1. Capital City Functions:**
#
# ...
